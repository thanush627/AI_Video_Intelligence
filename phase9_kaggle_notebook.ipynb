# %% [markdown]
# # Phase 9 Kaggle Notebook
#
# This notebook demonstrates speech-to-text style query processing and language handling for voice search.

# %%
# !pip install -q fastapi python-multipart
import sys, json
sys.path.append('/kaggle/working/AI_Video_Intelligence')
from ai.phase9.voice_search import Phase9VoiceSearch

processor = Phase9VoiceSearch(output_dir='/kaggle/working/AI_Video_Intelligence/outputs/phase9')
result = processor.process_query(query='Find the blue car near the person')
print(json.dumps(result, indent=2))
