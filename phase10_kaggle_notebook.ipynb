# %% [markdown]
# # Phase 10 Kaggle Notebook
#
# This notebook starts a lightweight FastAPI backend for search, upload, voice, and clip endpoints.

# %%
# !pip install -q fastapi uvicorn python-multipart
import sys, os
sys.path.append('/kaggle/working/AI_Video_Intelligence')
import nest_asyncio
nest_asyncio.apply()
from ai.phase10.api_app import app
import uvicorn

port = int(os.getenv('PORT', 8000))
uvicorn.run(app, host='0.0.0.0', port=port)
